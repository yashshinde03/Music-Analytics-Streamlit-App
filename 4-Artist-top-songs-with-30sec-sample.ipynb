# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
SPOTIPY_CLIENT_ID = ''
SPOTIPY_CLIENT_SECRET = ''
#SPOTIPY_REDIRECT_URL = 'your-app-redirect-url'

# %%
auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
artist_name = 'Katy Perry' #'Led Zeppelin'

# %% [markdown]
# ## Searching Artist

# %%
artists = sp.search(q='artist:'+artist_name,type='artist', limit=10)

# %%
artists
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3AKaty+Perry&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#     'followers': {'href': None, 'total': 22002639},
#     'genres': ['dance pop', 'pop', 'post-teen pop'],
#     'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#     'id': '6jJ0s89eD6GaHleKKya26X',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebdc9dcb7e4a97b4552e1224d6',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174dc9dcb7e4a97b4552e1224d6',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178dc9dcb7e4a97b4552e1224d6',
#       'width': 160}],
#     'name': 'Katy Perry',
#     'popularity': 83,
#     'type': 'artist',
#     'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jsDtDfNjHeIrNtx5sx4b1'},
#     'followers': {'href': None, 'total': 247},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6jsDtDfNjHeIrNtx5sx4b1',
#     'id': '6jsDtDfNjHeIrNtx5sx4b1',
#     'images': [],
#     'name': 'Made famous by Katy Perry',
#     'popularity': 11,
#     'type': 'artist',
#     'uri': 'spotify:artist:6jsDtDfNjHeIrNtx5sx4b1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/72S9ffNvi1wam83yQV05fH'},
#     'followers': {'href': None, 'total': 202},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/72S9ffNvi1wam83yQV05fH',
#     'id': '72S9ffNvi1wam83yQV05fH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27308942b1efe2adb9eb5516337',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0208942b1efe2adb9eb5516337',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485108942b1efe2adb9eb5516337',
#       'width': 64}],
#     'name': "Katy Perry Karaoke's Band",
#     'popularity': 6,
#     'type': 'artist',
#     'uri': 'spotify:artist:72S9ffNvi1wam83yQV05fH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wqobWgvgDpmCH6A5f6EbR'},
#     'followers': {'href': None, 'total': 247},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2wqobWgvgDpmCH6A5f6EbR',
#     'id': '2wqobWgvgDpmCH6A5f6EbR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273be519fce1f118053f4df4028',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02be519fce1f118053f4df4028',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851be519fce1f118053f4df4028',
#       'width': 64}],
#     'name': 'Katy Perry Tribute',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2wqobWgvgDpmCH6A5f6EbR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/57EpMiVlwVnv2kvGskCA1k'},
#     'followers': {'href': None, 'total': 678},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/57EpMiVlwVnv2kvGskCA1k',
#     'id': '57EpMiVlwVnv2kvGskCA1k',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a527a3b0fa125f23736c40e4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a527a3b0fa125f23736c40e4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a527a3b0fa125f23736c40e4',
#       'width': 64}],
#     'name': 'Tribute To Katy Perry',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:57EpMiVlwVnv2kvGskCA1k'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3bvKQjoxbJJjytqNVkAN98'},
#     'followers': {'href': None, 'total': 187},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3bvKQjoxbJJjytqNVkAN98',
#     'id': '3bvKQjoxbJJjytqNVkAN98',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273680e12214abc7edbd877a0f7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02680e12214abc7edbd877a0f7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851680e12214abc7edbd877a0f7',
#       'width': 64}],
#     'name': 'Katy Perry Tribute Team',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:3bvKQjoxbJJjytqNVkAN98'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5w5kwkHlfcpNxOSBDYEuk5'},
#     'followers': {'href': None, 'total': 125},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5w5kwkHlfcpNxOSBDYEuk5',
#     'id': '5w5kwkHlfcpNxOSBDYEuk5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739bfa7cfd3fda823475e9a695',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029bfa7cfd3fda823475e9a695',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519bfa7cfd3fda823475e9a695',
#       'width': 64}],
#     'name': 'Katy Perry Karaoke Band',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:5w5kwkHlfcpNxOSBDYEuk5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5b49WYJaBmap5HcqecZL6g'},
#     'followers': {'href': None, 'total': 122},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5b49WYJaBmap5HcqecZL6g',
#     'id': '5b49WYJaBmap5HcqecZL6g',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737d4ccf387af77ad35d898082',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027d4ccf387af77ad35d898082',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517d4ccf387af77ad35d898082',
#       'width': 64}],
#     'name': 'Katy Perry Piano Tribute Performers',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:5b49WYJaBmap5HcqecZL6g'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/076jUf2hFwIMOhSXS626Op'},
#     'followers': {'href': None, 'total': 158},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/076jUf2hFwIMOhSXS626Op',
#     'id': '076jUf2hFwIMOhSXS626Op',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fe17c339bdec820d9bcb3333',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fe17c339bdec820d9bcb3333',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fe17c339bdec820d9bcb3333',
#       'width': 64}],
#     'name': '#1 Katy Perry Tribute Band',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:076jUf2hFwIMOhSXS626Op'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/66baY8S7blE6glpQW35Wtf'},
#     'followers': {'href': None, 'total': 152},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/66baY8S7blE6glpQW35Wtf',
#     'id': '66baY8S7blE6glpQW35Wtf',
#     'images': [],
#     'name': 'Made Famous By Katy Perry & Snoop Dogg',
#     'popularity': 9,
#     'type': 'artist',
#     'uri': 'spotify:artist:66baY8S7blE6glpQW35Wtf'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=artist%3AKaty+Perry&type=artist&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 11}}

# %%
artists['artists']['items']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#   'followers': {'href': None, 'total': 22002639},
#   'genres': ['dance pop', 'pop', 'post-teen pop'],
#   'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#   'id': '6jJ0s89eD6GaHleKKya26X',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebdc9dcb7e4a97b4552e1224d6',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174dc9dcb7e4a97b4552e1224d6',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178dc9dcb7e4a97b4552e1224d6',
#     'width': 160}],
#   'name': 'Katy Perry',
#   'popularity': 83,
#   'type': 'artist',
#   'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jsDtDfNjHeIrNtx5sx4b1'},
#   'followers': {'href': None, 'total': 247},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/6jsDtDfNjHeIrNtx5sx4b1',
#   'id': '6jsDtDfNjHeIrNtx5sx4b1',
#   'images': [],
#   'name': 'Made famous by Katy Perry',
#   'popularity': 11,
#   'type': 'artist',
#   'uri': 'spotify:artist:6jsDtDfNjHeIrNtx5sx4b1'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/72S9ffNvi1wam83yQV05fH'},
#   'followers': {'href': None, 'total': 202},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/72S9ffNvi1wam83yQV05fH',
#   'id': '72S9ffNvi1wam83yQV05fH',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27308942b1efe2adb9eb5516337',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0208942b1efe2adb9eb5516337',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485108942b1efe2adb9eb5516337',
#     'width': 64}],
#   'name': "Katy Perry Karaoke's Band",
#   'popularity': 6,
#   'type': 'artist',
#   'uri': 'spotify:artist:72S9ffNvi1wam83yQV05fH'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wqobWgvgDpmCH6A5f6EbR'},
#   'followers': {'href': None, 'total': 247},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/2wqobWgvgDpmCH6A5f6EbR',
#   'id': '2wqobWgvgDpmCH6A5f6EbR',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273be519fce1f118053f4df4028',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02be519fce1f118053f4df4028',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851be519fce1f118053f4df4028',
#     'width': 64}],
#   'name': 'Katy Perry Tribute',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:2wqobWgvgDpmCH6A5f6EbR'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/57EpMiVlwVnv2kvGskCA1k'},
#   'followers': {'href': None, 'total': 678},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/57EpMiVlwVnv2kvGskCA1k',
#   'id': '57EpMiVlwVnv2kvGskCA1k',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273a527a3b0fa125f23736c40e4',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02a527a3b0fa125f23736c40e4',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851a527a3b0fa125f23736c40e4',
#     'width': 64}],
#   'name': 'Tribute To Katy Perry',
#   'popularity': 2,
#   'type': 'artist',
#   'uri': 'spotify:artist:57EpMiVlwVnv2kvGskCA1k'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3bvKQjoxbJJjytqNVkAN98'},
#   'followers': {'href': None, 'total': 187},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/3bvKQjoxbJJjytqNVkAN98',
#   'id': '3bvKQjoxbJJjytqNVkAN98',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273680e12214abc7edbd877a0f7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02680e12214abc7edbd877a0f7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851680e12214abc7edbd877a0f7',
#     'width': 64}],
#   'name': 'Katy Perry Tribute Team',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:3bvKQjoxbJJjytqNVkAN98'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5w5kwkHlfcpNxOSBDYEuk5'},
#   'followers': {'href': None, 'total': 125},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/5w5kwkHlfcpNxOSBDYEuk5',
#   'id': '5w5kwkHlfcpNxOSBDYEuk5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739bfa7cfd3fda823475e9a695',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029bfa7cfd3fda823475e9a695',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519bfa7cfd3fda823475e9a695',
#     'width': 64}],
#   'name': 'Katy Perry Karaoke Band',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:5w5kwkHlfcpNxOSBDYEuk5'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5b49WYJaBmap5HcqecZL6g'},
#   'followers': {'href': None, 'total': 122},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/5b49WYJaBmap5HcqecZL6g',
#   'id': '5b49WYJaBmap5HcqecZL6g',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737d4ccf387af77ad35d898082',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027d4ccf387af77ad35d898082',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517d4ccf387af77ad35d898082',
#     'width': 64}],
#   'name': 'Katy Perry Piano Tribute Performers',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:5b49WYJaBmap5HcqecZL6g'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/076jUf2hFwIMOhSXS626Op'},
#   'followers': {'href': None, 'total': 158},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/076jUf2hFwIMOhSXS626Op',
#   'id': '076jUf2hFwIMOhSXS626Op',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fe17c339bdec820d9bcb3333',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fe17c339bdec820d9bcb3333',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fe17c339bdec820d9bcb3333',
#     'width': 64}],
#   'name': '#1 Katy Perry Tribute Band',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:076jUf2hFwIMOhSXS626Op'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/66baY8S7blE6glpQW35Wtf'},
#   'followers': {'href': None, 'total': 152},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/66baY8S7blE6glpQW35Wtf',
#   'id': '66baY8S7blE6glpQW35Wtf',
#   'images': [],
#   'name': 'Made Famous By Katy Perry & Snoop Dogg',
#   'popularity': 9,
#   'type': 'artist',
#   'uri': 'spotify:artist:66baY8S7blE6glpQW35Wtf'}]

# %%
artists['artists']['items'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#  'followers': {'href': None, 'total': 22002639},
#  'genres': ['dance pop', 'pop', 'post-teen pop'],
#  'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#  'id': '6jJ0s89eD6GaHleKKya26X',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5ebdc9dcb7e4a97b4552e1224d6',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174dc9dcb7e4a97b4552e1224d6',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178dc9dcb7e4a97b4552e1224d6',
#    'width': 160}],
#  'name': 'Katy Perry',
#  'popularity': 83,
#  'type': 'artist',
#  'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}

# %%
artist_uri = artists['artists']['items'][0]['uri']
print(artist_uri)
# Out:
# spotify:artist:6jJ0s89eD6GaHleKKya26X

# %%
results = sp.artist_top_tracks(artist_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    if track['preview_url'] is not None:
        print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : When I’m Gone (with Katy Perry)
# cover art: https://i.scdn.co/image/ab67616d0000b27337940571b0be91d69b5fd0d6
#
# track    : Feels (feat. Pharrell Williams, Katy Perry & Big Sean)
# audio    : https://p.scdn.co/mp3-preview/abc3107d3b24c6e4aedd08a96d34ae4497ee4fc1?cid=bd88fe788a574f64a9e8f9c13f71ade1
# cover art: https://i.scdn.co/image/ab67616d0000b2734d3fa5ce7ba599f4fd7803ef
#
# track    : Unconditionally
# cover art: https://i.scdn.co/image/ab67616d0000b2731e9a057052d59004caf47e22
#
# track    : Roar
# cover art: https://i.scdn.co/image/ab67616d0000b2731e9a057052d59004caf47e22
#
# track    : Harleys In Hawaii
# cover art: https://i.scdn.co/image/ab67616d0000b2735ebe6cbd74a47a5e8ea88985
#
# track    : California Gurls
# cover art: https://i.scdn.co/image/ab67616d0000b273d20c38f295039520d688a888
#
# track    : Last Friday Night (T.G.I.F.)
# cover art: https://i.scdn.co/image/ab67616d0000b273d20c38f295039520d688a888
#
# track    : Dark Horse
# cover art: https://i.scdn.co/image/ab67616d0000b2731e9a057052d59004caf47e22
#
# track    : I Kissed A Girl
# cover art: https://i.scdn.co/image/ab67616d0000b273cd3978ebe35d93a07249b97f
#
# track    : Part Of Me
# cover art: https://i.scdn.co/image/ab67616d0000b273a56dc57d708c7b62db950105

# %%
results['tracks'][0]['preview_url']

# %%
from IPython.display import Audio

# %%
Audio(url=results['tracks'][1]['preview_url']+'.mp3', autoplay=False, embed=True)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
